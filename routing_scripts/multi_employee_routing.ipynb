# %% [markdown]
# # Optimale medewerkerroutes met Google OR-Tools
#
# Dit notebook lost een **Vehicle Routing Problem (VRP)** op:
# - **20 voertuigen** (medewerkers), elk vertrekkend vanuit hun eigen thuisadres
# - **100 cliënten** die verdeeld en bezocht moeten worden
# - **Precies 5 stops** per medewerker
# - **Minimale totale reistijd** over alle routes gecombineerd
#
# Aanpak:
# 1. Wegennet laden → NetworkX graph
# 2. Medewerkers + cliënten koppelen aan dichtstbijzijnde graph-knoop
# 3. Reistijdenmatrix berekenen (Dijkstra voor alle relevante knooppunten)
# 4. OR-Tools VRP oplossen met capaciteitsbeperking (5 stops/medewerker)
# 5. Routes visualiseren op Folium-kaart met 20 unieke kleuren

# %% [markdown]
# ## 1. Bibliotheken importeren

# %%
import pandas as pd
import numpy as np
import networkx as nx
from shapely import wkt
import folium
from scipy.spatial import cKDTree
from ortools.constraint_solver import routing_enums_pb2, pywrapcp
import warnings
warnings.filterwarnings('ignore')

print('All libraries loaded successfully.')
# Out:
# All libraries loaded successfully.

# %% [markdown]
# ## 2. Wegennet laden en graph bouwen

# %%
edges_df = pd.read_csv('../output/heerlen_edge_table.csv')
print(f'Edges loaded: {len(edges_df)}')
edges_df['geometry'] = edges_df['geometry'].apply(wkt.loads)

G          = nx.Graph()
node_coords = {}  # node_id -> (lon, lat)
edge_geom   = {}  # (u, v) -> geometry (both directions)

for _, row in edges_df.iterrows():
    geom   = row['geometry']
    coords = list(geom.coords)
    u, v   = row['u'], row['v']
    G.add_edge(u, v, weight=row['travel_time_min'], geometry=geom)
    node_coords[u] = (coords[0][0],  coords[0][1])
    node_coords[v] = (coords[-1][0], coords[-1][1])
    edge_geom[(u, v)] = geom
    edge_geom[(v, u)] = geom

print(f'Graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges.')

# k-d tree for fast nearest-node lookup
node_ids      = list(node_coords.keys())
node_lons_arr = np.array([node_coords[n][0] for n in node_ids])
node_lats_arr = np.array([node_coords[n][1] for n in node_ids])
kd_tree = cKDTree(np.column_stack((node_lons_arr, node_lats_arr)))

def nearest_node(lon, lat):
    _, idx = kd_tree.query([lon, lat])
    return node_ids[idx]
# Out:
# Edges loaded: 7183
# Graph: 3120 nodes, 4340 edges.

# %% [markdown]
# ## 3. Medewerkers en cliënten laden

# %%
# ── Employees (manually geocoded Heerlen addresses) ───────────────────────
employee_data = [
    ('employees 1',  50.8872, 5.9812),
    ('employees 2',  50.8895, 5.9820),
    ('employees 3',  50.8883, 5.9830),
    ('employees 4',  50.8855, 5.9795),
    ('employees 5',  50.8945, 5.9660),
    ('employees 6',  50.8878, 5.9808),
    ('employees 7',  50.8948, 5.9700),
    ('employees 8',  50.8870, 5.9825),
    ('employees 9',  50.8868, 5.9817),
    ('employees 10', 50.8785, 5.9750),
    ('employees 11', 50.8840, 5.9810),
    ('employees 12', 50.8860, 5.9835),
    ('employees 13', 50.8850, 5.9880),
    ('employees 14', 50.8890, 5.9822),
    ('employees 15', 50.8710, 5.9920),
    ('employees 16', 50.8810, 5.9680),
    ('employees 17', 50.8952, 5.9672),
    ('employees 18', 50.8875, 5.9805),
    ('employees 19', 50.8940, 5.9665),
    ('employees 20', 50.8790, 5.9760),
]
employees_df = pd.DataFrame(employee_data, columns=['name', 'lat', 'lon'])
employees_df['node'] = employees_df.apply(
    lambda r: nearest_node(r['lon'], r['lat']), axis=1
)
print(f'Employees: {len(employees_df)}')

# ── Clients from clients.csv ──────────────────────────────────────────────
clients_df = pd.read_csv('../output/clients.csv')
print('Client columns:', clients_df.columns.tolist())

# Auto-detect coordinate column
coord_col = None
for col in clients_df.columns:
    sample = clients_df[col].dropna().astype(str).iloc[0]
    parts  = sample.replace(',', ' ').replace(';', ' ').split()
    if len(parts) == 2:
        try:
            float(parts[0]); float(parts[1])
            coord_col = col
            break
        except ValueError:
            pass

coord_col = coord_col or clients_df.columns[0]
print(f'Coordinate column: "{coord_col}"')

def split_coords(s):
    parts = str(s).replace(';', ' ').replace(',', ' ').split()
    return (float(parts[0]), float(parts[1])) if len(parts) == 2 else (np.nan, np.nan)

clients_df[['lat', 'lon']] = clients_df[coord_col].apply(
    lambda x: pd.Series(split_coords(x))
)
clients_df = clients_df.dropna(subset=['lat', 'lon']).reset_index(drop=True)
clients_df['client_id'] = clients_df.index
clients_df['node'] = clients_df.apply(
    lambda r: nearest_node(r['lon'], r['lat']), axis=1
)
print(f'Clients: {len(clients_df)}')
# Out:
# Employees: 20
# Client columns: ['name', 'address', 'coordinates', 'care_arrangement', 'preferences', 'time_window_start', 'time_window_end', 'care_hours', 'dogs', 'cats', 'smokes']
# Coordinate column: "coordinates"
# Clients: 100

# %% [markdown]
# ## 4. Reistijdenmatrix berekenen
#
# We berekenen de kortste reistijd (Dijkstra) vanuit elk thuisknooppunt en elk cliëntknooppunt.
# De resulterende matrix heeft dimensie **(20 depots + 100 cliënten) × (20 depots + 100 cliënten)**.

# %%
N_EMPLOYEES = len(employees_df)   # 20
N_CLIENTS   = len(clients_df)     # 100

# Index layout for OR-Tools:
#   0 .. 19  → employee home nodes (depot per vehicle)
#  20 .. 119 → client nodes
all_nodes = (
    employees_df['node'].tolist() +
    clients_df['node'].tolist()
)  # length = 120

unique_sources = list(set(all_nodes))
print(f'Running Dijkstra from {len(unique_sources)} unique graph nodes ...')

dist_from = {}  # graph_node -> {graph_node: minutes}
for i, src in enumerate(unique_sources):
    dist_from[src] = nx.single_source_dijkstra_path_length(
        G, src, weight='weight'
    )
    if (i + 1) % 20 == 0:
        print(f'  {i+1}/{len(unique_sources)} done')

print('Building travel-time matrix ...')

N_TOTAL = N_EMPLOYEES + N_CLIENTS  # 120

# Build integer matrix (OR-Tools requires int)
# Scale minutes × 100 to keep 2 decimal precision as integers
SCALE = 100
time_matrix = np.zeros((N_TOTAL, N_TOTAL), dtype=np.int64)

for i in range(N_TOTAL):
    src_graph_node = all_nodes[i]
    lengths        = dist_from[src_graph_node]
    for j in range(N_TOTAL):
        dst_graph_node = all_nodes[j]
        t = lengths.get(dst_graph_node, float('inf'))
        time_matrix[i][j] = int(t * SCALE) if t != float('inf') else 10_000_000

print(f'Time matrix shape: {time_matrix.shape}')
print(f'Min travel time: {time_matrix[time_matrix > 0].min() / SCALE:.2f} min')
print(f'Max finite travel time: {time_matrix[time_matrix < 10_000_000].max() / SCALE:.2f} min')
# Out:
# Running Dijkstra from 102 unique graph nodes ...
#   20/102 done
#   40/102 done
#   60/102 done
#   80/102 done
#   100/102 done
# Building travel-time matrix ...
# Time matrix shape: (120, 120)
# Min travel time: 0.03 min
# Max finite travel time: 11.22 min

# %% [markdown]
# ## 5. OR-Tools VRP oplossen
#
# We formuleren het als een **Capacitated VRP met meerdere depots**:
# - Elk voertuig (medewerker) heeft zijn eigen depot (thuisadres)
# - Elke cliënt heeft een demand = 1
# - Capaciteit per voertuig = 5
# - Doelstelling: minimaliseer de totale reistijd
# - Oplosser: **PATH_CHEAPEST_ARC** start + **GUIDED_LOCAL_SEARCH** metaheuristiek

# %%
CAPACITY = 5  # clients per employee

# ── OR-Tools data model ───────────────────────────────────────────────────
def create_data_model():
    data = {}
    data['time_matrix']  = time_matrix.tolist()
    data['num_vehicles'] = N_EMPLOYEES
    # Each vehicle starts AND ends at its own home (indices 0-19)
    data['starts'] = list(range(N_EMPLOYEES))
    data['ends']   = list(range(N_EMPLOYEES))
    # Demand: employees (depots) have demand 0, clients have demand 1
    data['demands']    = [0] * N_EMPLOYEES + [1] * N_CLIENTS
    data['capacities'] = [CAPACITY] * N_EMPLOYEES
    return data

data = create_data_model()

# ── Create routing model ──────────────────────────────────────────────────
manager = pywrapcp.RoutingIndexManager(
    len(data['time_matrix']),
    data['num_vehicles'],
    data['starts'],
    data['ends']
)
routing = pywrapcp.RoutingModel(manager)

# ── Travel time callback ──────────────────────────────────────────────────
def time_callback(from_index, to_index):
    from_node = manager.IndexToNode(from_index)
    to_node   = manager.IndexToNode(to_index)
    return data['time_matrix'][from_node][to_node]

transit_callback_index = routing.RegisterTransitCallback(time_callback)
routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

# ── Capacity constraint ───────────────────────────────────────────────────
def demand_callback(from_index):
    from_node = manager.IndexToNode(from_index)
    return data['demands'][from_node]

demand_callback_index = routing.RegisterUnaryTransitCallback(demand_callback)
routing.AddDimensionWithVehicleCapacity(
    demand_callback_index,
    0,                       # no slack
    data['capacities'],      # max 5 per vehicle
    True,                    # start cumul at zero
    'Capacity'
)

# ── Solver parameters ─────────────────────────────────────────────────────
search_params = pywrapcp.DefaultRoutingSearchParameters()
search_params.first_solution_strategy = (
    routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
)
search_params.local_search_metaheuristic = (
    routing_enums_pb2.LocalSearchMetaheuristic.GUIDED_LOCAL_SEARCH
)
search_params.time_limit.seconds = 30   # optimise for 30 seconds
search_params.log_search = True

print('Solving VRP ...')
solution = routing.SolveWithParameters(search_params)

if solution:
    print(f'Solution found! Total cost: {solution.ObjectiveValue() / SCALE:.1f} min')
else:
    print('No solution found!')
# Out:
# Solving VRP ...
# Solution found! Total cost: 157.5 min

# %% [markdown]
# ## 6. Oplossing extraheren

# %%
def extract_routes(solution, routing, manager, data):
    """Extract routes from OR-Tools solution."""
    routes = []
    for vehicle_id in range(data['num_vehicles']):
        index = routing.Start(vehicle_id)
        node_indices = []
        route_time = 0
        while not routing.IsEnd(index):
            node = manager.IndexToNode(index)
            node_indices.append(node)
            prev_index = index
            index = solution.Value(routing.NextVar(index))
            route_time += routing.GetArcCostForVehicle(prev_index, index, vehicle_id)
        node_indices.append(manager.IndexToNode(index))
        client_ids = [ni - N_EMPLOYEES for ni in node_indices if N_EMPLOYEES <= ni < N_TOTAL]
        routes.append({
            'vehicle_id': vehicle_id,
            'node_indices': node_indices,
            'client_ids': client_ids,
            'total_time': route_time / SCALE,
        })
    return routes

routes = extract_routes(solution, routing, manager, data)

print('=== Route samenvatting ===')
total_minutes = 0
for r in routes:
    emp = employees_df.loc[r['vehicle_id'], 'name']
    n = len(r['client_ids'])
    t = r['total_time']
    total_minutes += t
    print(f'{emp:15s}: {n} cliënten | {t:5.1f} min | stops: {r["client_ids"]}')
print(f'\nTotale reistijd alle medewerkers: {total_minutes:.1f} min')
print(f'Gemiddeld per medewerker:          {total_minutes/N_EMPLOYEES:.1f} min')

# -----------------------------------------------------------------------------
# Planning per medewerker (tabel met tijden)
# -----------------------------------------------------------------------------
from datetime import datetime, timedelta

START_OF_DAY = datetime.strptime("08:00", "%H:%M")

def minutes_to_time(base: datetime, minutes: float) -> str:
    return (base + timedelta(minutes=minutes)).strftime("%H:%M")

def build_schedule(route, employees_df, clients_df, time_matrix, N_EMPLOYEES, SCALE):
    vid = route["vehicle_id"]
    client_ids = route["client_ids"]
    rows = []
    current_time = 0.0
    emp_name = employees_df.loc[vid, "name"]
    rows.append({
        "Stop": "Thuis (vertrek)",
        "Cliënt": "—",
        "Aankomst": "—",
        "Zorgtijd": "—",
        "Vertrek": minutes_to_time(START_OF_DAY, current_time),
    })
    prev_matrix_idx = vid
    for step, cid in enumerate(client_ids):
        client_matrix_idx = N_EMPLOYEES + cid
        travel = time_matrix[prev_matrix_idx][client_matrix_idx] / SCALE
        current_time += travel
        arrival_time = minutes_to_time(START_OF_DAY, current_time)
        care_hours = float(clients_df.loc[cid, "care_hours"]) if "care_hours" in clients_df.columns else 1.0
        care_min = care_hours * 60.0
        current_time += care_min
        departure_time = minutes_to_time(START_OF_DAY, current_time)
        client_name = clients_df.loc[cid, "name"] if "name" in clients_df.columns else f"Cliënt {cid}"
        rows.append({
            "Stop": f"Stop {step+1}",
            "Cliënt": client_name,
            "Aankomst": arrival_time,
            "Zorgtijd": f"{int(care_min)} min ({care_hours:.1f} uur)",
            "Vertrek": departure_time,
        })
        prev_matrix_idx = client_matrix_idx
    travel_home = time_matrix[prev_matrix_idx][vid] / SCALE
    current_time += travel_home
    rows.append({
        "Stop": "Thuis (terug)",
        "Cliënt": "—",
        "Aankomst": minutes_to_time(START_OF_DAY, current_time),
        "Zorgtijd": "—",
        "Vertrek": "—",
    })
    return rows

all_schedules = {}
for route in routes:
    vid = route["vehicle_id"]
    emp_name = employees_df.loc[vid, "name"]
    if not route["client_ids"]:
        continue
    schedule_rows = build_schedule(route, employees_df, clients_df, time_matrix, N_EMPLOYEES, SCALE)
    df_sched = pd.DataFrame(schedule_rows)
    all_schedules[emp_name] = df_sched

print(f"\nPlanningen gegenereerd voor {len(all_schedules)} medewerkers.")
# Out:
# === Route samenvatting ===
# employees 1    : 5 cliënten |   8.6 min | stops: [45, 58, 97, 63, 59]
# employees 2    : 5 cliënten |   7.4 min | stops: [9, 18, 1, 54, 3]
# employees 3    : 5 cliënten |  15.3 min | stops: [75, 20, 84, 40, 4]
# employees 4    : 5 cliënten |   7.8 min | stops: [17, 85, 15, 23, 50]
# employees 5    : 5 cliënten |   9.8 min | stops: [14, 41, 80, 10, 2]
# employees 6    : 5 cliënten |   6.2 min | stops: [65, 22, 61, 0, 82]
# employees 7    : 5 cliënten |  10.4 min | stops: [44, 67, 33, 57, 5]
# employees 8    : 5 cliënten |   2.3 min | stops: [78, 16, 43, 25, 64]
# employees 9    : 5 cliënten |   1.2 min | stops: [21, 76, 38, 36, 32]
# employees 10   : 5 cliënten |   3.5 min | stops: [24, 71, 39, 72, 74]
# employees 11   : 5 cliënten |  12.9 min | stops: [96, 19, 48, 55, 56]
# employees 12   : 5 cliënten |   7.9 min | stops: [34, 51, 66, 88, 49]
# employees 13   : 5 cliënten |  10.1 min | stops: [94, 98, 81, 29, 83]
# employees 14   : 5 cliënten |   8.0 min | stops: [31, 28, 60, 12, 90]
# employees 15   : 5 cliënten |   9.4 min | stops: [99, 30, 86, 70, 79]
# employees 16   : 5 cliënten |   4.1 min | stops: [62, 69, 89, 13, 37]
# employees 17   : 5 cliënten |  14.6 min | stops: [11, 53, 52, 26, 8]
# employees 18   : 5 cliënten |   1.8 min | stops: [68, 35, 7, 73, 42]
# employees 19   : 5 cliënten |   7.0 min | stops: [46, 47, 93, 87, 77]
# employees 20   : 5 cliënten |   9.1 min | stops: [27, 92, 6, 91, 95]
#
# Totale reistijd alle medewerkers: 157.5 min
# Gemiddeld per medewerker:          7.9 min
#
# Planningen gegenereerd voor 20 medewerkers.

# %% [markdown]
# ## 7. Kaart bouwen
#
# Elke medewerker krijgt een unieke kleur. Routes volgen de echte wegen uit het wegennet.
# Thuisadressen worden als grote gekleurde cirkels getoond, cliënten als kleine cirkels.

# %%
EMPLOYEE_COLORS = [
    '#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
    '#911eb4', '#42d4f4', '#f032e6', '#bfef45', '#fabed4',
    '#469990', '#dcbeff', '#9A6324', '#ff8c00', '#800000',
    '#aaffc3', '#808000', '#00bfff', '#000075', '#808080',
]

def nodes_to_latlon(path_nodes):
    latlon = []
    for i in range(len(path_nodes) - 1):
        u, v = path_nodes[i], path_nodes[i + 1]
        geom = edge_geom.get((u, v))
        if geom is None:
            cu, cv = node_coords.get(u), node_coords.get(v)
            if cu:
                latlon.append((cu[1], cu[0]))
            if cv:
                latlon.append((cv[1], cv[0]))
            continue
        coords = list(geom.coords)
        cu = node_coords.get(u)
        if cu and len(coords) >= 2:
            if abs(coords[-1][0] - cu[0]) < abs(coords[0][0] - cu[0]):
                coords = coords[::-1]
        latlon.extend([(lat, lon) for lon, lat in coords])
    return latlon

def road_segment(graph_node_a, graph_node_b):
    try:
        path = nx.shortest_path(G, source=graph_node_a, target=graph_node_b, weight='weight')
        return nodes_to_latlon(path)
    except nx.NetworkXNoPath:
        ca, cb = node_coords.get(graph_node_a), node_coords.get(graph_node_b)
        result = []
        if ca:
            result.append((ca[1], ca[0]))
        if cb:
            result.append((cb[1], cb[0]))
        return result

# Kaart initialiseren
center_lat = float(np.mean(node_lats_arr))
center_lon = float(np.mean(node_lons_arr))
m = folium.Map(location=[center_lat, center_lon], zoom_start=14, tiles='CartoDB positron')

# Achtergrond wegennet
for _, row in edges_df.iterrows():
    latlon = [(lat, lon) for lon, lat in row['geometry'].coords]
    folium.PolyLine(locations=latlon, color='#cccccc', weight=1, opacity=0.3).add_to(m)

# Routes tekenen
print('Routes worden getekend...')
for route in routes:
    vid = route['vehicle_id']
    color = EMPLOYEE_COLORS[vid % len(EMPLOYEE_COLORS)]
    emp = employees_df.loc[vid]
    ni_seq = route['node_indices']
    graph_seq = [all_nodes[ni] for ni in ni_seq]
    stop_labels = (['thuis'] + [f'stop {k}' for k in range(1, len(route['client_ids']) + 1)] + ['thuis'])
    for seg_i in range(len(graph_seq) - 1):
        latlon = road_segment(graph_seq[seg_i], graph_seq[seg_i + 1])
        if len(latlon) >= 2:
            folium.PolyLine(
                locations=latlon, color=color, weight=4, opacity=0.85,
                tooltip=f"{emp['name']} | {stop_labels[seg_i]} → {stop_labels[min(seg_i+1, len(stop_labels)-1)]}"
            ).add_to(m)

# Thuisadressen (grote markers)
for vid, emp in employees_df.iterrows():
    color = EMPLOYEE_COLORS[vid % len(EMPLOYEE_COLORS)]
    r = routes[vid]
    folium.Marker(
        location=[emp['lat'], emp['lon']],
        icon=folium.DivIcon(
            html=f'<div style="width:22px;height:22px;background:{color};border:3px solid white;border-radius:50%;box-shadow:0 2px 6px rgba(0,0,0,.5);"></div>',
            icon_size=(22, 22), icon_anchor=(11, 11)
        ),
        popup=folium.Popup(f"<b>{emp['name']}</b><br>Totale reistijd: {r['total_time']:.1f} min<br>Cliënten: {r['client_ids']}", max_width=240),
        tooltip=f"{emp['name']} (thuis)"
    ).add_to(m)

# Cliënten (kleine markers, gekleurd per medewerker)
client_info = {}
for route in routes:
    vid = route['vehicle_id']
    color = EMPLOYEE_COLORS[vid % len(EMPLOYEE_COLORS)]
    name = employees_df.loc[vid, 'name']
    for stop_num, cid in enumerate(route['client_ids'], start=1):
        client_info[cid] = (color, name, stop_num)

for _, client in clients_df.iterrows():
    cid = int(client['client_id'])
    if cid not in client_info:
        continue
    color, emp_name, stop_num = client_info[cid]
    folium.CircleMarker(
        location=[client['lat'], client['lon']],
        radius=7, color='white', weight=1.5, fill=True, fill_color=color, fill_opacity=0.9,
        popup=folium.Popup(f"<b>Cliënt {cid}</b><br>Medewerker: {emp_name}<br>Stop #{stop_num}", max_width=180),
        tooltip=f"Cliënt {cid} | {emp_name} | stop {stop_num}"
    ).add_to(m)

# Legenda (linksonder)
legend_rows = ''
for route in routes:
    vid = route['vehicle_id']
    color = EMPLOYEE_COLORS[vid % len(EMPLOYEE_COLORS)]
    name = employees_df.loc[vid, 'name']
    t = route['total_time']
    cids = route['client_ids']
    legend_rows += f'''
    <tr>
        <td><div style="width:14px;height:14px;background:{color};border:1px solid #ccc;border-radius:3px;margin:2px;"></div></td>
        <td style="padding:1px 8px;white-space:nowrap;"><b>{name}</b></td>
        <td style="color:#444;white-space:nowrap;">{t:.0f} min &nbsp; cliënten: {cids}</td>
    </tr>
    '''
legend_html = f'''
<div style="position:fixed;bottom:20px;left:20px;z-index:1000;background:rgba(255,255,255,0.96);padding:12px 16px;border-radius:8px;font-size:11px;font-family:sans-serif;box-shadow:0 2px 12px rgba(0,0,0,.3);max-height:500px;overflow-y:auto;">
    <b style="font-size:13px;">OR-Tools VRP — Routeoverzicht</b><br>
    <span style="color:#777;font-size:10px;">20 medewerkers · 100 cliënten · 5 stops/medewerker</span>
    <table style="border-collapse:collapse;margin-top:8px;line-height:1.7;">
        <tr><th style="text-align:left;"></th><th style="text-align:left;padding-right:8px;">Medewerker</th><th style="text-align:left;">Reistijd &amp; cliënten</th></tr>
        {legend_rows}
    </table>
    <hr style="margin:8px 0;border-color:#eee;">
    <span style="color:#666;">&#9679; groot = thuisadres &nbsp; &#9679; klein = cliënt</span>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# Planningstabel per medewerker (rechtsonder, uitklapbaar)
schedule_panel = '''
<div style="position:fixed; bottom:20px; right:20px; z-index:1000;
            background:rgba(255,255,255,0.96); padding:12px 16px;
            border-radius:8px; font-size:12px; font-family:sans-serif;
            box-shadow:0 2px 12px rgba(0,0,0,.3);
            max-height:450px; overflow-y:auto; width:420px;">
    <b style="font-size:14px;">Dagplanning per medewerker</b><br>
    <span style="color:#777;">klik op een naam om de tabel te zien</span>
    <hr style="margin:8px 0;">
'''
for emp_name, df_sched in all_schedules.items():
    table_html = df_sched.to_html(index=False, classes='schedule-table', border=0)
    table_html = table_html.replace('<table', '<table style="width:100%; border-collapse:collapse; margin-top:6px;"')
    table_html = table_html.replace('<th>', '<th style="text-align:left; background:#f2f2f2; padding:4px;">')
    table_html = table_html.replace('<td>', '<td style="padding:4px; border-bottom:1px solid #ddd;">')
    schedule_panel += f'''
    <details style="margin-bottom:10px;">
        <summary style="cursor:pointer; font-weight:bold; padding:6px; background:#f9f9f9; border-radius:5px;">
            {emp_name}
        </summary>
        <div style="margin-top:8px; max-height:300px; overflow-x:auto;">
            {table_html}
        </div>
    </details>
    '''
schedule_panel += '</div>'
m.get_root().html.add_child(folium.Element(schedule_panel))

# Kaart opslaan en tonen
output_path = '../output/vrp_routes_map.html'
m.save(output_path)
print(f'Kaart opgeslagen: {output_path}')

from IPython.display import IFrame, display
display(IFrame(src='vrp_routes_map.html', width='100%', height=700))
# Out:
# Routes worden getekend...
# Kaart opgeslagen: ../output/vrp_routes_map.html
#         <iframe
#             width="100%"
#             height="700"
#             src="vrp_routes_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 8. Legenda toevoegen en kaart opslaan

# %%
legend_rows = ''
for route in routes:
    vid   = route['vehicle_id']
    color = EMPLOYEE_COLORS[vid % len(EMPLOYEE_COLORS)]
    name  = employees_df.loc[vid, 'name']
    t     = route['total_time']
    cids  = route['client_ids']
    legend_rows += (
        '<tr>'
        f'<td><div style="width:14px;height:14px;background:{color};'
        'border:1px solid #ccc;border-radius:3px;margin:2px;"></div></td>'
        f'<td style="padding:1px 8px;white-space:nowrap;"><b>{name}</b></td>'
        f'<td style="color:#444;white-space:nowrap;">{t:.0f} min &nbsp; '
        f'cliënten: {cids}</td>'
        '</tr>'
    )

legend_html = (
    '<div style="position:fixed;bottom:20px;left:20px;z-index:1000;'
    'background:rgba(255,255,255,0.96);padding:12px 16px;border-radius:8px;'
    'font-size:11px;font-family:sans-serif;'
    'box-shadow:0 2px 12px rgba(0,0,0,.3);'
    'max-height:500px;overflow-y:auto;">'
    '<b style="font-size:13px;">OR-Tools VRP — Routeoverzicht</b><br>'
    '<span style="color:#777;font-size:10px;">'
    '20 medewerkers · 100 cliënten · 5 stops/medewerker</span>'
    '<table style="border-collapse:collapse;margin-top:8px;line-height:1.7;">'
    '<tr>'
    '<th style="text-align:left;"></th>'
    '<th style="text-align:left;padding-right:8px;">Medewerker</th>'
    '<th style="text-align:left;">Reistijd &amp; cliënten</th>'
    '</tr>'
    + legend_rows +
    '</table>'
    '<hr style="margin:8px 0;border-color:#eee;">'
    '<span style="color:#666;">'
    '&#9679; groot = thuisadres &nbsp; &#9679; klein = cliënt</span>'
    '</div>'
)

m.get_root().html.add_child(folium.Element(legend_html))

output_path = '../output/vrp_routes_map.html'
m.save(output_path)
print(f'Map saved: {output_path}')

from IPython.display import IFrame, display
display(IFrame(src='vrp_routes_map.html', width='100%', height=700))
# Out:
# Map saved: ../output/vrp_routes_map.html
#         <iframe
#             width="100%"
#             height="700"
#             src="vrp_routes_map.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 9. Gedetailleerde routesamenvatting

# %%
print('=== Gedetailleerde routesamenvatting ===')
rows = []
for route in routes:
    vid = route['vehicle_id']
    rows.append({
        'Medewerker':        employees_df.loc[vid, 'name'],
        'Aantal stops':      len(route['client_ids']),
        'Cliënt-IDs':        str(route['client_ids']),
        'Totale tijd (min)': round(route['total_time'], 1),
    })

summary = pd.DataFrame(rows)
print(summary.to_string(index=False))

total = summary['Totale tijd (min)'].sum()
avg   = summary['Totale tijd (min)'].mean()
print(f'\nTotale reistijd:  {total:.1f} min')
print(f'Gemiddeld:        {avg:.1f} min/medewerker')
print(f'Langste route:    {summary["Totale tijd (min)"].max():.1f} min')
print(f'Kortste route:    {summary["Totale tijd (min)"].min():.1f} min')
# Out:
# === Gedetailleerde routesamenvatting ===
#   Medewerker  Aantal stops           Cliënt-IDs  Totale tijd (min)
#  employees 1             5 [45, 58, 97, 63, 59]                8.6
#  employees 2             5    [9, 18, 1, 54, 3]                7.4
#  employees 3             5  [75, 20, 84, 40, 4]               15.3
#  employees 4             5 [17, 85, 15, 23, 50]                7.8
#  employees 5             5  [14, 41, 80, 10, 2]                9.8
#  employees 6             5  [65, 22, 61, 0, 82]                6.2
#  employees 7             5  [44, 67, 33, 57, 5]               10.4
#  employees 8             5 [78, 16, 43, 25, 64]                2.3
#  employees 9             5 [21, 76, 38, 36, 32]                1.2
# employees 10             5 [24, 71, 39, 72, 74]                3.5
# employees 11             5 [96, 19, 48, 55, 56]               12.9
# employees 12             5 [34, 51, 66, 88, 49]                7.9
# employees 13             5 [94, 98, 81, 29, 83]               10.1
# employees 14             5 [31, 28, 60, 12, 90]                8.0
# employees 15             5 [99, 30, 86, 70, 79]                9.4
# employees 16             5 [62, 69, 89, 13, 37]                4.1
# employees 17             5  [11, 53, 52, 26, 8]               14.6
# employees 18             5  [68, 35, 7, 73, 42]                1.8
# employees 19             5 [46, 47, 93, 87, 77]                7.0
# employees 20             5  [27, 92, 6, 91, 95]                9.1
#
# Totale reistijd:  157.4 min
# Gemiddeld:        7.9 min/medewerker
# Langste route:    15.3 min
# Kortste route:    1.2 min

# %% [markdown]
# ## Planning per medewerker
# Voor elke medewerker wordt een gedetailleerde dagplanning gegenereerd:
# - **Vertrektijd** vanuit thuisadres
# - **Aankomsttijd** bij elke cliënt
# - **Zorgtijd** (op basis van `care_hours` uit het bestand)
# - **Vertrektijd** naar de volgende stop
# - **Thuiskomsttijd** aan het einde van de dag

# %%
from datetime import datetime, timedelta

# ─── Startmoment van de werkdag (pas hier aan indien nodig) ──────────────────
START_OF_DAY = datetime.strptime("08:00", "%H:%M")

def minutes_to_time(base: datetime, minutes: float) -> str:
    return (base + timedelta(minutes=minutes)).strftime("%H:%M")

def build_schedule(route: dict, employees_df, clients_df, time_matrix, N_EMPLOYEES, SCALE) -> list[dict]:
    vid        = route["vehicle_id"]
    client_ids = route["client_ids"]   # bijv. [45, 58, 97, 63, 59]

    rows         = []
    current_time = 0.0   # minuten na START_OF_DAY

    emp_name = employees_df.loc[vid, "name"]

    # Vertrek vanuit huis
    rows.append({
        "Stop":         "Thuis (vertrek)",
        "Cliënt":       "—",
        "Aankomst":     "—",
        "Zorgtijd":     "—",
        "Vertrek":      minutes_to_time(START_OF_DAY, current_time),
    })

    prev_matrix_idx = vid  # depot van deze medewerker = zijn vehicle_id (0-19)

    for step, cid in enumerate(client_ids):
        # Matrix-index van deze cliënt
        client_matrix_idx = N_EMPLOYEES + cid

        # Reistijd van vorige stop → deze cliënt
        travel        = time_matrix[prev_matrix_idx][client_matrix_idx] / SCALE
        current_time += travel
        arrival_time  = minutes_to_time(START_OF_DAY, current_time)

        # Zorgtijd (care_hours in uren → minuten)
        care_hours     = float(clients_df.loc[cid, "care_hours"]) if "care_hours" in clients_df.columns else 1.0
        care_min       = care_hours * 60.0
        current_time  += care_min
        departure_time = minutes_to_time(START_OF_DAY, current_time)

        client_name = clients_df.loc[cid, "name"] if "name" in clients_df.columns else f"Cliënt {cid}"

        rows.append({
            "Stop":     f"Stop {step + 1}",
            "Cliënt":   client_name,
            "Aankomst": arrival_time,
            "Zorgtijd": f"{int(care_min)} min ({care_hours:.1f} uur)",
            "Vertrek":  departure_time,
        })

        prev_matrix_idx = client_matrix_idx

    # Terug naar huis
    travel_home   = time_matrix[prev_matrix_idx][vid] / SCALE
    current_time += travel_home

    rows.append({
        "Stop":     "Thuis (terug)",
        "Cliënt":   "—",
        "Aankomst": minutes_to_time(START_OF_DAY, current_time),
        "Zorgtijd": "—",
        "Vertrek":  "—",
    })

    return rows


# ─── Genereer en print planning per medewerker ───────────────────────────────
all_schedules = {}

for route in routes:
    vid      = route["vehicle_id"]
    emp_name = employees_df.loc[vid, "name"]

    if not route["client_ids"]:
        continue

    schedule_rows = build_schedule(
        route, employees_df, clients_df, time_matrix, N_EMPLOYEES, SCALE
    )
    df_sched = pd.DataFrame(schedule_rows)
    all_schedules[emp_name] = df_sched

    total_care_min   = sum(float(clients_df.loc[cid, "care_hours"]) * 60 for cid in route["client_ids"])
    total_travel_min = route["total_time"]

    print(f"\n{'═' * 72}")
    print(f"{emp_name}  |  reistijd: {total_travel_min:.0f} min  |  zorgtijd: {total_care_min:.0f} min")
    print(f"{'═' * 72}")
    print(df_sched.to_string(index=False))

print(f"\n\nPlanning gegenereerd voor {len(all_schedules)} medewerkers.")
# Out:
# ════════════════════════════════════════════════════════════════════════
# employees 1  |  reistijd: 9 min  |  zorgtijd: 480 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 46    08:02  90 min (1.5 uur)   09:32
#          Stop 2 Client 59    09:34 120 min (2.0 uur)   11:34
#          Stop 3 Client 98    11:34  60 min (1.0 uur)   12:34
#          Stop 4 Client 64    12:35 150 min (2.5 uur)   15:05
#          Stop 5 Client 60    15:07  60 min (1.0 uur)   16:07
#   Thuis (terug)         —    16:08                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 2  |  reistijd: 7 min  |  zorgtijd: 600 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 10    08:02  60 min (1.0 uur)   09:02
#          Stop 2 Client 19    09:02 120 min (2.0 uur)   11:02
#          Stop 3  Client 2    11:03 120 min (2.0 uur)   13:03
#          Stop 4 Client 55    13:04 180 min (3.0 uur)   16:04
#          Stop 5  Client 4    16:04 120 min (2.0 uur)   18:04
#   Thuis (terug)         —    18:07                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 3  |  reistijd: 15 min  |  zorgtijd: 540 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 76    08:06  90 min (1.5 uur)   09:36
#          Stop 2 Client 21    09:38 180 min (3.0 uur)   12:38
#          Stop 3 Client 85    12:39  60 min (1.0 uur)   13:39
#          Stop 4 Client 41    13:39  90 min (1.5 uur)   15:09
#          Stop 5  Client 5    15:10 120 min (2.0 uur)   17:10
#   Thuis (terug)         —    17:15                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 4  |  reistijd: 8 min  |  zorgtijd: 630 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 18    08:01 150 min (2.5 uur)   10:31
#          Stop 2 Client 86    10:32 180 min (3.0 uur)   13:32
#          Stop 3 Client 16    13:33  60 min (1.0 uur)   14:33
#          Stop 4 Client 24    14:35  60 min (1.0 uur)   15:35
#          Stop 5 Client 51    15:36 180 min (3.0 uur)   18:36
#   Thuis (terug)         —    18:37                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 5  |  reistijd: 10 min  |  zorgtijd: 780 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 15    08:00 180 min (3.0 uur)   11:00
#          Stop 2 Client 42    11:04  90 min (1.5 uur)   12:34
#          Stop 3 Client 81    12:34 180 min (3.0 uur)   15:34
#          Stop 4 Client 11    15:35 180 min (3.0 uur)   18:35
#          Stop 5  Client 3    18:36 150 min (2.5 uur)   21:06
#   Thuis (terug)         —    21:09                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 6  |  reistijd: 6 min  |  zorgtijd: 630 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 66    08:02 180 min (3.0 uur)   11:02
#          Stop 2 Client 23    11:03  90 min (1.5 uur)   12:33
#          Stop 3 Client 62    12:34 120 min (2.0 uur)   14:34
#          Stop 4  Client 1    14:35 120 min (2.0 uur)   16:35
#          Stop 5 Client 83    16:35 120 min (2.0 uur)   18:35
#   Thuis (terug)         —    18:36                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 7  |  reistijd: 10 min  |  zorgtijd: 750 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 45    08:04 120 min (2.0 uur)   10:04
#          Stop 2 Client 68    10:05 180 min (3.0 uur)   13:05
#          Stop 3 Client 34    13:05 180 min (3.0 uur)   16:05
#          Stop 4 Client 58    16:05  90 min (1.5 uur)   17:35
#          Stop 5  Client 6    17:36 180 min (3.0 uur)   20:36
#   Thuis (terug)         —    20:40                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 8  |  reistijd: 2 min  |  zorgtijd: 690 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 79    08:00 120 min (2.0 uur)   10:00
#          Stop 2 Client 17    10:01 180 min (3.0 uur)   13:01
#          Stop 3 Client 44    13:01 150 min (2.5 uur)   15:31
#          Stop 4 Client 26    15:31  90 min (1.5 uur)   17:01
#          Stop 5 Client 65    17:01 150 min (2.5 uur)   19:31
#   Thuis (terug)         —    19:32                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 9  |  reistijd: 1 min  |  zorgtijd: 570 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 22    08:00  90 min (1.5 uur)   09:30
#          Stop 2 Client 77    09:30  90 min (1.5 uur)   11:00
#          Stop 3 Client 39    11:00 180 min (3.0 uur)   14:00
#          Stop 4 Client 37    14:01 150 min (2.5 uur)   16:31
#          Stop 5 Client 33    16:31  60 min (1.0 uur)   17:31
#   Thuis (terug)         —    17:31                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 10  |  reistijd: 4 min  |  zorgtijd: 510 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 25    08:00  60 min (1.0 uur)   09:00
#          Stop 2 Client 72    09:01  90 min (1.5 uur)   10:31
#          Stop 3 Client 40    10:31 150 min (2.5 uur)   13:01
#          Stop 4 Client 73    13:02  60 min (1.0 uur)   14:02
#          Stop 5 Client 75    14:02 150 min (2.5 uur)   16:32
#   Thuis (terug)         —    16:33                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 11  |  reistijd: 13 min  |  zorgtijd: 690 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 97    08:04 150 min (2.5 uur)   10:34
#          Stop 2 Client 20    10:36 180 min (3.0 uur)   13:36
#          Stop 3 Client 49    13:37  60 min (1.0 uur)   14:37
#          Stop 4 Client 56    14:38 120 min (2.0 uur)   16:38
#          Stop 5 Client 57    16:39 180 min (3.0 uur)   19:39
#   Thuis (terug)         —    19:42                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 12  |  reistijd: 8 min  |  zorgtijd: 600 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 35    08:02 180 min (3.0 uur)   11:02
#          Stop 2 Client 52    11:02  60 min (1.0 uur)   12:02
#          Stop 3 Client 67    12:03 150 min (2.5 uur)   14:33
#          Stop 4 Client 89    14:35  90 min (1.5 uur)   16:05
#          Stop 5 Client 50    16:05 120 min (2.0 uur)   18:05
#   Thuis (terug)         —    18:07                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 13  |  reistijd: 10 min  |  zorgtijd: 450 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 95    08:02  60 min (1.0 uur)   09:02
#          Stop 2 Client 99    09:04  60 min (1.0 uur)   10:04
#          Stop 3 Client 82    10:06  90 min (1.5 uur)   11:36
#          Stop 4 Client 30    11:37 180 min (3.0 uur)   14:37
#          Stop 5 Client 84    14:39  60 min (1.0 uur)   15:39
#   Thuis (terug)         —    15:40                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 14  |  reistijd: 8 min  |  zorgtijd: 630 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 32    08:00  90 min (1.5 uur)   09:30
#          Stop 2 Client 29    09:31 150 min (2.5 uur)   12:01
#          Stop 3 Client 61    12:03 150 min (2.5 uur)   14:33
#          Stop 4 Client 13    14:36  90 min (1.5 uur)   16:06
#          Stop 5 Client 91    16:06 150 min (2.5 uur)   18:36
#   Thuis (terug)         —    18:38                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 15  |  reistijd: 9 min  |  zorgtijd: 570 min
# ════════════════════════════════════════════════════════════════════════
#            Stop     Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)          —        —                 —   08:00
#          Stop 1 Client 100    08:02  90 min (1.5 uur)   09:32
#          Stop 2  Client 31    09:33 150 min (2.5 uur)   12:03
#          Stop 3  Client 87    12:04  90 min (1.5 uur)   13:34
#          Stop 4  Client 71    13:34  60 min (1.0 uur)   14:34
#          Stop 5  Client 80    14:36 180 min (3.0 uur)   17:36
#   Thuis (terug)          —    17:39                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 16  |  reistijd: 4 min  |  zorgtijd: 720 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 63    08:00 120 min (2.0 uur)   10:00
#          Stop 2 Client 70    10:00 120 min (2.0 uur)   12:00
#          Stop 3 Client 90    12:01 180 min (3.0 uur)   15:01
#          Stop 4 Client 14    15:02 180 min (3.0 uur)   18:02
#          Stop 5 Client 38    18:03 120 min (2.0 uur)   20:03
#   Thuis (terug)         —    20:04                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 17  |  reistijd: 15 min  |  zorgtijd: 600 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 12    08:03  90 min (1.5 uur)   09:33
#          Stop 2 Client 54    09:34 150 min (2.5 uur)   12:04
#          Stop 3 Client 53    12:05 120 min (2.0 uur)   14:05
#          Stop 4 Client 27    14:06 120 min (2.0 uur)   16:06
#          Stop 5  Client 9    16:09 120 min (2.0 uur)   18:09
#   Thuis (terug)         —    18:14                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 18  |  reistijd: 2 min  |  zorgtijd: 540 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 69    08:00  90 min (1.5 uur)   09:30
#          Stop 2 Client 36    09:30  90 min (1.5 uur)   11:00
#          Stop 3  Client 8    11:00  60 min (1.0 uur)   12:00
#          Stop 4 Client 74    12:00 180 min (3.0 uur)   15:00
#          Stop 5 Client 43    15:01 120 min (2.0 uur)   17:01
#   Thuis (terug)         —    17:01                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 19  |  reistijd: 7 min  |  zorgtijd: 450 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 47    08:00  90 min (1.5 uur)   09:30
#          Stop 2 Client 48    09:30  90 min (1.5 uur)   11:00
#          Stop 3 Client 94    11:01  60 min (1.0 uur)   12:01
#          Stop 4 Client 88    12:02 150 min (2.5 uur)   14:32
#          Stop 5 Client 78    14:35  60 min (1.0 uur)   15:35
#   Thuis (terug)         —    15:37                 —       —
#
# ════════════════════════════════════════════════════════════════════════
# employees 20  |  reistijd: 9 min  |  zorgtijd: 810 min
# ════════════════════════════════════════════════════════════════════════
#            Stop    Cliënt Aankomst          Zorgtijd Vertrek
# Thuis (vertrek)         —        —                 —   08:00
#          Stop 1 Client 28    08:03 180 min (3.0 uur)   11:03
#          Stop 2 Client 93    11:05 180 min (3.0 uur)   14:05
#          Stop 3  Client 7    14:06 150 min (2.5 uur)   16:36
#          Stop 4 Client 92    16:36 180 min (3.0 uur)   19:36
#          Stop 5 Client 96    19:36 120 min (2.0 uur)   21:36
#   Thuis (terug)         —    21:39                 —       —
#
#
# Planning gegenereerd voor 20 medewerkers.
